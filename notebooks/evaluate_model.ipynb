# %% [markdown]
# This notebook demonstrates evaluating a small sample with BERTScore (if available) and TF-IDF cosine similarity using the evaluate script.

# %%
from scripts import colab_helpers
from evaluate import evaluate_model
refs = ["Xin chào, tôi là NPC."]
hyps = ["Xin chào, tôi là một nhân vật trong game."]
metrics = evaluate_model.compute_metrics(refs, hyps)
print(metrics)
